# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential, layers
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Activation, Flatten, BatchNormalization, Input ,concatenate
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import  EarlyStopping, ModelCheckpoint
import glob
import os
import PIL
import time

from IPython import display

# %%
def make_generator_model():
    model = tf.keras.Sequential()
    model.add(layers.Dense(7*7*256, use_bias=False, input_shape=(100,)))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Reshape((7, 7, 256)))
    assert model.output_shape == (None, 7, 7, 256) # Note: None is the batch size

    model.add(layers.Conv2DTranspose(128, (5, 5), strides=(1, 1), padding='same', use_bias=False))
    assert model.output_shape == (None, 7, 7, 128)
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Conv2DTranspose(64, (5, 5), strides=(2, 2), padding='same', use_bias=False))
    assert model.output_shape == (None, 14, 14, 64)
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Conv2DTranspose(1, (5, 5), strides=(2, 2), padding='same', use_bias=False, activation='tanh'))
    assert model.output_shape == (None, 28, 28, 1)

    return model

# %%
def make_discriminator_model():
    model = tf.keras.Sequential()
    model.add(layers.Conv2D(64, (5, 5), strides=(2, 2), padding='same',
                                     input_shape=[28, 28, 1]))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))

    model.add(layers.Conv2D(128, (5, 5), strides=(2, 2), padding='same'))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))

    model.add(layers.Flatten())
    model.add(layers.Dense(1))

    return model

# %%
generator = make_generator_model()
discriminator = make_discriminator_model()
generator_optimizer = tf.keras.optimizers.Adam(1e-4)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)

# %%
checkpoint_dir = '/content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/training_checkpoints_old'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer,
                                 generator=generator,
                                 discriminator=discriminator)

# %%
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
noi = tf.random.normal([1, 100])
sample = checkpoint.generator(noi, training=False)
plt.imshow(sample[0, :, :, 0], cmap='gray')

# %%
disc = checkpoint.discriminator
disc.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 14, 14, 64)        1664
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 14, 14, 64)        0
#
#  dropout (Dropout)           (None, 14, 14, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 128)         204928
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 7, 7, 128)         0
#
#  dropout_1 (Dropout)         (None, 7, 7, 128)         0
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense_1 (Dense)             (None, 1)                 6273
#
# =================================================================
# Total params: 212,865
# Trainable params: 212,865
# Non-trainable params: 0
# _________________________________________________________________

# %%
val = disc(sample)
print (val)
# Out:
# tf.Tensor([[0.1819657]], shape=(1, 1), dtype=float32)

# %% [markdown]
# Now, we transfer the weights of discriminator to a new model, with the only difference being that the new model's last dense layer has 10 parameters instead of 1.

# %%
new_model = Sequential()

for i in range(len(disc.layers) - 1):
    new_model.add(disc.layers[i])

# Freeze the layers 
for layer in new_model.layers:
    layer.trainable = True  #Unfreezed as True
# new_model.add(Dense(128))
# new_model.add(Dense(10, activation='softmax'))
new_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 14, 14, 64)        1664
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 14, 14, 64)        0
#
#  dropout (Dropout)           (None, 14, 14, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 128)         204928
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 7, 7, 128)         0
#
#  dropout_1 (Dropout)         (None, 7, 7, 128)         0
#
#  flatten (Flatten)           (None, 6272)              0
#
# =================================================================
# Total params: 206,592
# Trainable params: 206,592
# Non-trainable params: 0
# _________________________________________________________________

# %%
# view the initialized weights and bias of the last dense layer; weights are uniformly randomly generated 
# and biases are all zeroes by default
new_model.layers[-1].weights
# Out:
# []

# %%
(train_img, train_lb), (test_img, test_lb) = tf.keras.datasets.mnist.load_data()

print(train_img.shape, train_lb.shape, test_img.shape, test_lb.shape, '\n')

# set random seed
np.random.seed(42)
trainsize = 10000  # number of training images we use, selected randomly
randtrain = np.random.choice(train_img.shape[0], trainsize, replace=False)
X_train, y_train = train_img[randtrain], train_lb[randtrain]

np.random.seed(10)
testsize = 10000  # number of testing images we use, selected randomly
randtest = np.random.choice(test_img.shape[0], testsize, replace=False)
X_test, y_test = test_img[randtest], test_lb[randtest]

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# (60000, 28, 28) (60000,) (10000, 28, 28) (10000,)
#
# (10000, 28, 28) (10000,) (10000, 28, 28) (10000,)

# %%
train_images = X_train.reshape((trainsize, 28, 28, 1))
train_images = (train_images.astype('float32') - 127.5) / 127.5

test_images = X_test.reshape((testsize, 28, 28, 1))
test_images = (test_images.astype('float32') - 127.5) / 127.5

train_labels = to_categorical(y_train)
test_labels = to_categorical(y_test)

# %%
import skimage.data as skid
import cv2
import pylab as plt
import numpy as np
import cv2
from sklearn.cluster import MiniBatchKMeans
import pickle
import tqdm.notebook as tqdm

def generate_vector(gray):
  Detector = cv2.xfeatures2d.SIFT_create() ## cv2.FastFeatureDetector.create()
  Descriptor = cv2.xfeatures2d.SIFT_create()
  vector_64 = np.zeros(64,dtype='uint8')
  step_size = 5
  kp = Detector.detect(gray)
  if(len(kp)<8):
        return vector_64
  # kp = [cv2.KeyPoint(x, y, step_size) for y in range(0, gray.shape[0], step_size) 
  #                                     for x in range(0, gray.shape[1], step_size)]
  kp, desc = Descriptor.compute(gray, kp)
  kmeans = MiniBatchKMeans(n_clusters=8, n_init=10)
  kmeans.fit(desc)
  predictions = kmeans.predict(X=desc,  sample_weight=None)
  for pre in predictions:
    vector_64[pre] +=1
  return vector_64

# multiple images train
stack_tr = generate_vector(X_train[0])
count = 0
for img in tqdm.tqdm(X_train[1:]):
    vector = generate_vector(img)
    stack_tr = np.vstack((stack_tr,vector))
    count +=1
print("Histogram Generated for training set! ")
# multiple images train
stack_ts = generate_vector(X_test[0])
count = 0
for img in tqdm.tqdm(X_test[1:]):
    vector = generate_vector(img)
    stack_ts = np.vstack((stack_ts,vector))
    count +=1
print("Histogram Generated for testing set! ")
# Out:
#   0%|          | 0/9999 [00:00<?, ?it/s]
# Histogram Generated for training set!
#   0%|          | 0/9999 [00:00<?, ?it/s]
# Histogram Generated for testing set!

# %%
# np.save("/content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/MNIST_SIFT_histogram_train.npy",stack_tr)
# np.save("/content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/MNIST_SIFT_histogram_test.npy",stack_ts)
#
# stack_tr = np.load("/content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/MNIST_SIFT_histogram_train.npy")
# stack_ts = np.load("/content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/MNIST_SIFT_histogram_test.npy")

# %%
def ExtractFeatures_Layer(dim):
    model = Sequential()
    model.add(Dense(64,input_dim=dim,kernel_regularizer=l2(0.01)
                    ))
    model.add(Dropout(0.5))
    return model
DSIFT = ExtractFeatures_Layer(stack_tr.shape[1])
MergeModel = concatenate([new_model.output, DSIFT.output])

# %%
# new_model.add(Dense(10, activation='softmax'))
m = Dense(32, activation='relu')(MergeModel)
m = Dropout(0.5)(m)
m = Dense(10, activation='softmax')(m)

fin_model = Model(inputs=[new_model.input, DSIFT.input], outputs=m)
fin_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  conv2d_input (InputLayer)      [(None, 28, 28, 1)]  0           []
#
#  conv2d (Conv2D)                (None, 14, 14, 64)   1664        ['conv2d_input[0][0]']
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 14, 14, 64)   0           ['conv2d[1][0]']
#
#  dropout (Dropout)              (None, 14, 14, 64)   0           ['leaky_re_lu_3[1][0]']
#
#  conv2d_1 (Conv2D)              (None, 7, 7, 128)    204928      ['dropout[1][0]']
#
#  leaky_re_lu_4 (LeakyReLU)      (None, 7, 7, 128)    0           ['conv2d_1[1][0]']
#
#  dense_2_input (InputLayer)     [(None, 64)]         0           []
#
#  dropout_1 (Dropout)            (None, 7, 7, 128)    0           ['leaky_re_lu_4[1][0]']
#
#  dense_2 (Dense)                (None, 64)           4160        ['dense_2_input[0][0]']
#
#  flatten (Flatten)              (None, 6272)         0           ['dropout_1[1][0]']
#
#  dropout_2 (Dropout)            (None, 64)           0           ['dense_2[0][0]']
#
#  concatenate (Concatenate)      (None, 6336)         0           ['flatten[1][0]',
#                                                                   'dropout_2[0][0]']
#
#  dense_3 (Dense)                (None, 32)           202784      ['concatenate[0][0]']
#
#  dropout_3 (Dropout)            (None, 32)           0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 10)           330         ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 413,866
# Trainable params: 413,866
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
fin_model.compile(Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-7),
                  loss='categorical_crossentropy',
                  metrics=['accuracy',tf.keras.metrics.CategoricalCrossentropy()])

# %%
train_images.shape, stack_tr.shape, train_labels.shape, stack_ts.shape
# Out:
# ((10000, 28, 28, 1), (10000, 64), (10000, 10), (10000, 64))

# %%
filepath = "/content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_SIFT(only)NET_"+"MNIST"+"_best_weights.hdf5"
early_stop = EarlyStopping(monitor='val_accuracy', patience=50,mode='max')
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint,early_stop]

history2 = fin_model.fit([train_images,stack_tr], train_labels, batch_size=100, epochs=20
                        ,validation_data=([test_images,stack_ts], test_labels),
                         callbacks = callbacks_list,
                        )
# Out:
# Epoch 1/20
# 100/100 [==============================] - ETA: 0s - loss: 1.3030 - accuracy: 0.6829 - categorical_crossentropy: 0.9519
# Epoch 1: val_accuracy improved from -inf to 0.92200, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_SIFT(only)NET_MNIST_best_weights.hdf5
# 100/100 [==============================] - 26s 255ms/step - loss: 1.3030 - accuracy: 0.6829 - categorical_crossentropy: 0.9519 - val_loss: 0.4392 - val_accuracy: 0.9220 - val_categorical_crossentropy: 0.2894
# Epoch 2/20
# 100/100 [==============================] - ETA: 0s - loss: 0.6203 - accuracy: 0.8246 - categorical_crossentropy: 0.5462
# Epoch 2: val_accuracy improved from 0.92200 to 0.93920, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_SIFT(only)NET_MNIST_best_weights.hdf5
# 100/100 [==============================] - 23s 233ms/step - loss: 0.6203 - accuracy: 0.8246 - categorical_crossentropy: 0.5462 - val_loss: 0.2339 - val_accuracy: 0.9392 - val_categorical_crossentropy: 0.2064
# Epoch 3/20
# 100/100 [==============================] - ETA: 0s - loss: 0.4527 - accuracy: 0.8565 - categorical_crossentropy: 0.4400
# Epoch 3: val_accuracy improved from 0.93920 to 0.95230, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_SIFT(only)NET_MNIST_best_weights.hdf5
# 100/100 [==============================] - 23s 233ms/step - loss: 0.4527 - accuracy: 0.8565 - categorical_crossentropy: 0.4400 - val_loss: 0.1730 - val_accuracy: 0.9523 - val_categorical_crossentropy: 0.1688
# Epoch 4/20
# 100/100 [==============================] - ETA: 0s - loss: 0.3826 - accuracy: 0.8758 - categorical_crossentropy: 0.3806
# Epoch 4: val_accuracy did not improve from 0.95230
# 100/100 [==============================] - 23s 229ms/step - loss: 0.3826 - accuracy: 0.8758 - categorical_crossentropy: 0.3806 - val_loss: 0.1683 - val_accuracy: 0.9498 - val_categorical_crossentropy: 0.1675
# Epoch 5/20
# 100/100 [==============================] - ETA: 0s - loss: 0.3460 - accuracy: 0.8826 - categorical_crossentropy: 0.3456
# Epoch 5: val_accuracy improved from 0.95230 to 0.96310, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_SIFT(only)NET_MNIST_best_weights.hdf5
# 100/100 [==============================] - 23s 232ms/step - loss: 0.3460 - accuracy: 0.8826 - categorical_crossentropy: 0.3456 - val_loss: 0.1250 - val_accuracy: 0.9631 - val_categorical_crossentropy: 0.1248
# Epoch 6/20
# 100/100 [==============================] - ETA: 0s - loss: 0.3014 - accuracy: 0.8975 - categorical_crossentropy: 0.3013
# Epoch 6: val_accuracy improved from 0.96310 to 0.96460, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_SIFT(only)NET_MNIST_best_weights.hdf5
# 100/100 [==============================] - 24s 242ms/step - loss: 0.3014 - accuracy: 0.8975 - categorical_crossentropy: 0.3013 - val_loss: 0.1200 - val_accuracy: 0.9646 - val_categorical_crossentropy: 0.1199
# Epoch 7/20
# 100/100 [==============================] - ETA: 0s - loss: 0.2876 - accuracy: 0.9053 - categorical_crossentropy: 0.2875
# Epoch 7: val_accuracy improved from 0.96460 to 0.96710, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_SIFT(only)NET_MNIST_best_weights.hdf5
# 100/100 [==============================] - 25s 244ms/step - loss: 0.2876 - accuracy: 0.9053 - categorical_crossentropy: 0.2875 - val_loss: 0.1107 - val_accuracy: 0.9671 - val_categorical_crossentropy: 0.1105
# Epoch 8/20
# 100/100 [==============================] - ETA: 0s - loss: 0.2706 - accuracy: 0.9101 - categorical_crossentropy: 0.2705
# Epoch 8: val_accuracy improved from 0.96710 to 0.96800, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_SIFT(only)NET_MNIST_best_weights.hdf5
# 100/100 [==============================] - 24s 239ms/step - loss: 0.2706 - accuracy: 0.9101 - categorical_crossentropy: 0.2705 - val_loss: 0.1115 - val_accuracy: 0.9680 - val_categorical_crossentropy: 0.1114
# Epoch 9/20
# 100/100 [==============================] - ETA: 0s - loss: 0.2577 - accuracy: 0.9115 - categorical_crossentropy: 0.2576
# Epoch 9: val_accuracy did not improve from 0.96800
# 100/100 [==============================] - 23s 233ms/step - loss: 0.2577 - accuracy: 0.9115 - categorical_crossentropy: 0.2576 - val_loss: 0.1116 - val_accuracy: 0.9676 - val_categorical_crossentropy: 0.1115
# Epoch 10/20
# 100/100 [==============================] - ETA: 0s - loss: 0.2398 - accuracy: 0.9231 - categorical_crossentropy: 0.2397
# Epoch 10: val_accuracy did not improve from 0.96800
# 100/100 [==============================] - 23s 234ms/step - loss: 0.2398 - accuracy: 0.9231 - categorical_crossentropy: 0.2397 - val_loss: 0.1056 - val_accuracy: 0.9665 - val_categorical_crossentropy: 0.1055
# Epoch 11/20
# 100/100 [==============================] - ETA: 0s - loss: 0.2326 - accuracy: 0.9243 - categorical_crossentropy: 0.2325
# Epoch 11: val_accuracy improved from 0.96800 to 0.97030, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_SIFT(only)NET_MNIST_best_weights.hdf5
# 100/100 [==============================] - 23s 235ms/step - loss: 0.2326 - accuracy: 0.9243 - categorical_crossentropy: 0.2325 - val_loss: 0.0991 - val_accuracy: 0.9703 - val_categorical_crossentropy: 0.0989
# Epoch 12/20
# 100/100 [==============================] - ETA: 0s - loss: 0.2269 - accuracy: 0.9200 - categorical_crossentropy: 0.2268
# Epoch 12: val_accuracy improved from 0.97030 to 0.97090, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_SIFT(only)NET_MNIST_best_weights.hdf5
# 100/100 [==============================] - 23s 235ms/step - loss: 0.2269 - accuracy: 0.9200 - categorical_crossentropy: 0.2268 - val_loss: 0.1000 - val_accuracy: 0.9709 - val_categorical_crossentropy: 0.0999
# Epoch 13/20
# 100/100 [==============================] - ETA: 0s - loss: 0.2184 - accuracy: 0.9264 - categorical_crossentropy: 0.2183
# Epoch 13: val_accuracy did not improve from 0.97090
# 100/100 [==============================] - 23s 232ms/step - loss: 0.2184 - accuracy: 0.9264 - categorical_crossentropy: 0.2183 - val_loss: 0.1029 - val_accuracy: 0.9708 - val_categorical_crossentropy: 0.1029
# Epoch 14/20
# 100/100 [==============================] - ETA: 0s - loss: 0.2106 - accuracy: 0.9280 - categorical_crossentropy: 0.2105
# Epoch 14: val_accuracy did not improve from 0.97090
# 100/100 [==============================] - 23s 233ms/step - loss: 0.2106 - accuracy: 0.9280 - categorical_crossentropy: 0.2105 - val_loss: 0.1020 - val_accuracy: 0.9703 - val_categorical_crossentropy: 0.1018
# Epoch 15/20
# 100/100 [==============================] - ETA: 0s - loss: 0.2209 - accuracy: 0.9250 - categorical_crossentropy: 0.2208
# Epoch 15: val_accuracy did not improve from 0.97090
# 100/100 [==============================] - 25s 251ms/step - loss: 0.2209 - accuracy: 0.9250 - categorical_crossentropy: 0.2208 - val_loss: 0.1016 - val_accuracy: 0.9709 - val_categorical_crossentropy: 0.1015
# Epoch 16/20
# 100/100 [==============================] - ETA: 0s - loss: 0.1989 - accuracy: 0.9321 - categorical_crossentropy: 0.1988
# Epoch 16: val_accuracy improved from 0.97090 to 0.97230, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_SIFT(only)NET_MNIST_best_weights.hdf5
# 100/100 [==============================] - 23s 234ms/step - loss: 0.1989 - accuracy: 0.9321 - categorical_crossentropy: 0.1988 - val_loss: 0.0938 - val_accuracy: 0.9723 - val_categorical_crossentropy: 0.0937
# Epoch 17/20
# 100/100 [==============================] - ETA: 0s - loss: 0.1827 - accuracy: 0.9358 - categorical_crossentropy: 0.1826
# Epoch 17: val_accuracy did not improve from 0.97230
# 100/100 [==============================] - 23s 232ms/step - loss: 0.1827 - accuracy: 0.9358 - categorical_crossentropy: 0.1826 - val_loss: 0.1069 - val_accuracy: 0.9717 - val_categorical_crossentropy: 0.1068
# Epoch 18/20
# 100/100 [==============================] - ETA: 0s - loss: 0.1936 - accuracy: 0.9339 - categorical_crossentropy: 0.1935
# Epoch 18: val_accuracy improved from 0.97230 to 0.97240, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_SIFT(only)NET_MNIST_best_weights.hdf5
# 100/100 [==============================] - 24s 237ms/step - loss: 0.1936 - accuracy: 0.9339 - categorical_crossentropy: 0.1935 - val_loss: 0.0958 - val_accuracy: 0.9724 - val_categorical_crossentropy: 0.0957
# Epoch 19/20
# 100/100 [==============================] - ETA: 0s - loss: 0.1804 - accuracy: 0.9402 - categorical_crossentropy: 0.1803
# Epoch 19: val_accuracy did not improve from 0.97240
# 100/100 [==============================] - 23s 232ms/step - loss: 0.1804 - accuracy: 0.9402 - categorical_crossentropy: 0.1803 - val_loss: 0.0931 - val_accuracy: 0.9721 - val_categorical_crossentropy: 0.0930
# Epoch 20/20
# 100/100 [==============================] - ETA: 0s - loss: 0.1896 - accuracy: 0.9335 - categorical_crossentropy: 0.1895
# Epoch 20: val_accuracy improved from 0.97240 to 0.97340, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_SIFT(only)NET_MNIST_best_weights.hdf5
# 100/100 [==============================] - 24s 236ms/step - loss: 0.1896 - accuracy: 0.9335 - categorical_crossentropy: 0.1895 - val_loss: 0.0925 - val_accuracy: 0.9734 - val_categorical_crossentropy: 0.0925

# %%
accuracy = history2.history['accuracy']
val_accuracy = history2.history['val_accuracy']

plt.figure()
plt.plot(accuracy, label='accuracy')
plt.plot(val_accuracy, label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.3, 1])
plt.legend(loc='lower right')
plt.show()

# %%
loss = history2.history['loss']
val_loss = history2.history['val_loss']

plt.figure()
plt.plot(loss, label='loss')
plt.plot(val_loss, label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# We can see that, using the tuned discriminator model, both training accuracy and testing are approximately 0.90 after 15 epochs.

# %%
stack_ts[i].shape, stack_ts[i].reshape(1,64).shape, test_images[i].shape, test_images[i].reshape(1,28,28,1).shape
# Out:
# ((64,), (1, 64), (28, 28, 1), (1, 28, 28, 1))

# %%
# demonstration: predict the ith test digit
i = 15
prediction = fin_model.predict([test_images[i].reshape(1,28,28,1),stack_ts[i].reshape(1,64)])

# get probability distribution and classification of the test digit
print(prediction)
print('prediction:', np.argmax(prediction))

# draw the barplot
plt.figure()
plt.bar(np.arange(0,10).astype('str'), prediction[0,:])
plt.show()
# Out:
# 1/1 [==============================] - 0s 103ms/step
# [[2.4720015e-10 5.0456350e-10 9.9999821e-01 1.2521690e-06 3.3182720e-11
#   2.5728890e-13 9.7759517e-13 1.6705032e-07 3.0047642e-07 1.8595232e-10]]
# prediction: 2

# %%
# show the actual ith digit
print('actual label:', np.argmax(test_labels[i]))
plt.figure()
plt.imshow(test_images[i,:,:,0], cmap='gray')
plt.show()
# Out:
# actual label: 2

# %%
pred_labels = fin_model.predict([test_images,stack_ts]).argmax(axis=1)
true_labels = test_labels.argmax(axis=1)
# Out:
# 313/313 [==============================] - 5s 17ms/step

# %%
from sklearn.metrics import confusion_matrix
confusion_mat = confusion_matrix(true_labels, pred_labels)
confusion_mat
# Out:
# array([[ 969,    0,    0,    0,    0,    0,    7,    1,    3,    0],
#        [   0, 1116,    7,    2,    1,    1,    2,    1,    5,    0],
#        [   5,    1, 1002,    7,    3,    0,    0,    5,    9,    0],
#        [   0,    0,    4,  998,    0,    2,    0,    2,    3,    1],
#        [   1,    2,    3,    0,  954,    0,    6,    0,    2,   14],
#        [   2,    0,    0,   10,    0,  870,    5,    0,    5,    0],
#        [   5,    3,    0,    0,    1,    9,  936,    0,    4,    0],
#        [   1,    4,   30,    7,    4,    0,    0,  970,    3,    9],
#        [   2,    0,    2,    7,    1,    4,    2,    3,  950,    3],
#        [   8,    2,    2,    9,    3,    6,    1,    2,    7,  969]])

# %%
import numpy as np
confusion_mat = [[ 969,    0,    0,    0,    0,    0,    7,    1,    3,    0],
       [   0, 1116,    7,    2,    1,    1,    2,    1,    5,    0],
       [   5,    1, 1002,    7,    3,    0,    0,    5,    9,    0],
       [   0,    0,    4,  998,    0,    2,    0,    2,    3,    1],
       [   1,    2,    3,    0,  954,    0,    6,    0,    2,   14],
       [   2,    0,    0,   10,    0,  870,    5,    0,    5,    0],
       [   5,    3,    0,    0,    1,    9,  936,    0,    4,    0],
       [   1,    4,   30,    7,    4,    0,    0,  970,    3,    9],
       [   2,    0,    2,    7,    1,    4,    2,    3,  950,    3],
       [   8,    2,    2,    9,    3,    6,    1,    2,    7,  969]]
confusion_mat = np.array(confusion_mat)

# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline
from matplotlib import pyplot as plt

confusion_mat_norm = np.around(confusion_mat.astype('float') / np.atleast_2d(confusion_mat.sum(axis=1)).T, decimals=2)

classes = np.arange(0,10).astype('str')
confusion_mat_df = pd.DataFrame(confusion_mat_norm,
                                index = classes, 
                                columns = classes)

figure = plt.figure()
sns.heatmap(confusion_mat_df, annot=True, cmap=plt.cm.Blues)
# plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
# plt.show()
# Out:
# Text(0.5, 15.0, 'Predicted label')

# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline
from matplotlib import pyplot as plt

confusion_mat_norm = np.around(confusion_mat.astype('float') / np.atleast_2d(confusion_mat.sum(axis=1)).T, decimals=2)
fig, ax = plt.subplots(figsize=(12, 8))
import string
# classes = list(string.ascii_uppercase)
classes = np.arange(0,10).astype('str')
confusion_mat_df = pd.DataFrame(confusion_mat_norm,
                                index = classes, 
                                columns = classes)
sns.heatmap(confusion_mat_df, ax=ax,annot=True, cbar_kws={'label': 'Accuracy %'}, cmap=sns.color_palette("Blues",8))
# sns.heatmap(confusion_mat_df, annot=True, cmap=plt.cm.Blues, linewidths=.5, ax=ax, cbar_kws={'label': 'Accuracy %'})
plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
# plt.show()
