# %%
# !python3 -m pip uninstall opencv-python
# !python3 -m pip uninstall opencv-contrib-python
# !python3 -m pip install opencv-contrib-python==3.4.8.29
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting opencv-contrib-python==3.4.8.29
#   Downloading opencv_contrib_python-3.4.8.29-cp38-cp38-manylinux1_x86_64.whl (34.2 MB)
#      |████████████████████████████████| 34.2 MB 2.1 MB/s
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from opencv-contrib-python==3.4.8.29) (1.21.6)
# Installing collected packages: opencv-contrib-python
# Successfully installed opencv-contrib-python-3.4.8.29

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential, layers
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Activation, Flatten, BatchNormalization, Input ,concatenate
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import  EarlyStopping, ModelCheckpoint
import glob
import os
import PIL
import time

from IPython import display

# %%
def make_generator_model():
    model = tf.keras.Sequential()
    model.add(layers.Dense(7*7*256, use_bias=False, input_shape=(100,)))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Reshape((7, 7, 256)))
    assert model.output_shape == (None, 7, 7, 256) # Note: None is the batch size

    model.add(layers.Conv2DTranspose(128, (5, 5), strides=(1, 1), padding='same', use_bias=False))
    assert model.output_shape == (None, 7, 7, 128)
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Conv2DTranspose(64, (5, 5), strides=(2, 2), padding='same', use_bias=False))
    assert model.output_shape == (None, 14, 14, 64)
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Conv2DTranspose(1, (5, 5), strides=(2, 2), padding='same', use_bias=False, activation='tanh'))
    assert model.output_shape == (None, 28, 28, 1)

    return model

# %%
def make_discriminator_model():
    model = tf.keras.Sequential()
    model.add(layers.Conv2D(64, (5, 5), strides=(2, 2), padding='same',
                                     input_shape=[28, 28, 1]))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))

    model.add(layers.Conv2D(128, (5, 5), strides=(2, 2), padding='same'))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))

    model.add(layers.Flatten())
    model.add(layers.Dense(1))

    return model

# %%
generator = make_generator_model()
discriminator = make_discriminator_model()
generator_optimizer = tf.keras.optimizers.Adam(1e-4)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)

# %%
checkpoint_dir = '/content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/training_checkpoints_old'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer,
                                 generator=generator,
                                 discriminator=discriminator)

# %%
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
noi = tf.random.normal([1, 100])
sample = checkpoint.generator(noi, training=False)
plt.imshow(sample[0, :, :, 0], cmap='gray')

# %%
disc = checkpoint.discriminator
disc.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 14, 14, 64)        1664
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 14, 14, 64)        0
#
#  dropout (Dropout)           (None, 14, 14, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 128)         204928
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 7, 7, 128)         0
#
#  dropout_1 (Dropout)         (None, 7, 7, 128)         0
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense_1 (Dense)             (None, 1)                 6273
#
# =================================================================
# Total params: 212,865
# Trainable params: 212,865
# Non-trainable params: 0
# _________________________________________________________________

# %%
val = disc(sample)
print (val)
# Out:
# tf.Tensor([[-0.6436261]], shape=(1, 1), dtype=float32)

# %% [markdown]
# Now, we transfer the weights of discriminator to a new model, with the only difference being that the new model's last dense layer has 10 parameters instead of 1.

# %%
new_model = Sequential()

for i in range(len(disc.layers) - 1):
    new_model.add(disc.layers[i])

# Freeze the layers 
for layer in new_model.layers:
    layer.trainable = True  #Unfreezed as True
# new_model.add(Dense(128))
# new_model.add(Dense(10, activation='softmax'))
new_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 14, 14, 64)        1664
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 14, 14, 64)        0
#
#  dropout (Dropout)           (None, 14, 14, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 128)         204928
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 7, 7, 128)         0
#
#  dropout_1 (Dropout)         (None, 7, 7, 128)         0
#
#  flatten (Flatten)           (None, 6272)              0
#
# =================================================================
# Total params: 206,592
# Trainable params: 206,592
# Non-trainable params: 0
# _________________________________________________________________

# %%
# view the initialized weights and bias of the last dense layer; weights are uniformly randomly generated 
# and biases are all zeroes by default
new_model.layers[-1].weights
# Out:
# []

# %%
(train_img, train_lb), (test_img, test_lb) = tf.keras.datasets.mnist.load_data()

print(train_img.shape, train_lb.shape, test_img.shape, test_lb.shape, '\n')

# set random seed
np.random.seed(42)
trainsize = 10000  # number of training images we use, selected randomly
randtrain = np.random.choice(train_img.shape[0], trainsize, replace=False)
X_train, y_train = train_img[randtrain], train_lb[randtrain]

np.random.seed(10)
testsize = 10000  # number of testing images we use, selected randomly
randtest = np.random.choice(test_img.shape[0], testsize, replace=False)
X_test, y_test = test_img[randtest], test_lb[randtest]

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step
# (60000, 28, 28) (60000,) (10000, 28, 28) (10000,)
#
# (10000, 28, 28) (10000,) (10000, 28, 28) (10000,)

# %%
train_images = X_train.reshape((trainsize, 28, 28, 1))
train_images = (train_images.astype('float32') - 127.5) / 127.5

test_images = X_test.reshape((testsize, 28, 28, 1))
test_images = (test_images.astype('float32') - 127.5) / 127.5

train_labels = to_categorical(y_train)
test_labels = to_categorical(y_test)

# %%
import skimage.data as skid
import cv2
import pylab as plt
import numpy as np
import cv2
from sklearn.cluster import MiniBatchKMeans
import pickle
import tqdm.notebook as tqdm

def generate_vector(gray):
  Detector = cv2.KAZE_create() ## cv2.FastFeatureDetector.create()
  Descriptor = cv2.KAZE_create()
  vector_64 = np.zeros(64,dtype='uint8')
  step_size = 5
  kp = Detector.detect(gray)
  if(len(kp)<8):
        return vector_64
  # kp = [cv2.KeyPoint(x, y, step_size) for y in range(0, gray.shape[0], step_size) 
  #                                     for x in range(0, gray.shape[1], step_size)]
  kp, desc = Descriptor.compute(gray, kp)
  kmeans = MiniBatchKMeans(n_clusters=8, n_init=10)
  kmeans.fit(desc)
  predictions = kmeans.predict(X=desc,  sample_weight=None)
  for pre in predictions:
    vector_64[pre] +=1
  return vector_64

# multiple images train
stack_tr = generate_vector(X_train[0])
count = 0
for img in tqdm.tqdm(X_train[1:]):
    vector = generate_vector(img)
    stack_tr = np.vstack((stack_tr,vector))
    count +=1
print("Histogram Generated for training set! ")
# multiple images train
stack_ts = generate_vector(X_test[0])
count = 0
for img in tqdm.tqdm(X_test[1:]):
    vector = generate_vector(img)
    stack_ts = np.vstack((stack_ts,vector))
    count +=1
print("Histogram Generated for testing set! ")

# %%
# np.save("/content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/MNIST_ORB_histogram_train.npy",stack_tr)
# np.save("/content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/MNIST_ORB_histogram_test.npy",stack_ts)
#
stack_tr = np.load("/content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/MNIST_ORB_histogram_train.npy")
stack_ts = np.load("/content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/MNIST_ORB_histogram_test.npy")

# %%
def ExtractFeatures_Layer(dim):
    model = Sequential()
    model.add(Dense(64,input_dim=dim,kernel_regularizer=l2(0.01)
                    ))
    model.add(Dropout(0.5))
    return model
DSIFT = ExtractFeatures_Layer(stack_tr.shape[1])
MergeModel = concatenate([new_model.output, DSIFT.output])

# %%
# new_model.add(Dense(10, activation='softmax'))
m = Dense(32, activation='relu')(MergeModel)
m = Dropout(0.5)(m)
m = Dense(10, activation='softmax')(m)

fin_model = Model(inputs=[new_model.input, DSIFT.input], outputs=m)
fin_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  conv2d_input (InputLayer)      [(None, 28, 28, 1)]  0           []
#
#  conv2d (Conv2D)                (None, 14, 14, 64)   1664        ['conv2d_input[0][0]']
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 14, 14, 64)   0           ['conv2d[1][0]']
#
#  dropout (Dropout)              (None, 14, 14, 64)   0           ['leaky_re_lu_3[1][0]']
#
#  conv2d_1 (Conv2D)              (None, 7, 7, 128)    204928      ['dropout[1][0]']
#
#  leaky_re_lu_4 (LeakyReLU)      (None, 7, 7, 128)    0           ['conv2d_1[1][0]']
#
#  dense_2_input (InputLayer)     [(None, 64)]         0           []
#
#  dropout_1 (Dropout)            (None, 7, 7, 128)    0           ['leaky_re_lu_4[1][0]']
#
#  dense_2 (Dense)                (None, 64)           4160        ['dense_2_input[0][0]']
#
#  flatten (Flatten)              (None, 6272)         0           ['dropout_1[1][0]']
#
#  dropout_2 (Dropout)            (None, 64)           0           ['dense_2[0][0]']
#
#  concatenate (Concatenate)      (None, 6336)         0           ['flatten[1][0]',
#                                                                   'dropout_2[0][0]']
#
#  dense_3 (Dense)                (None, 32)           202784      ['concatenate[0][0]']
#
#  dropout_3 (Dropout)            (None, 32)           0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 10)           330         ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 413,866
# Trainable params: 413,866
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
fin_model.compile(Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-7),
                  loss='categorical_crossentropy',
                  metrics=['accuracy',tf.keras.metrics.CategoricalCrossentropy()])

# %%
train_images.shape, stack_tr.shape, train_labels.shape, stack_ts.shape
# Out:
# ((10000, 28, 28, 1), (10000, 64), (10000, 10), (10000, 64))

# %%
filepath = "/content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_ORB(only)NET_"+"MNIST"+"_best_weights.hdf5"
early_stop = EarlyStopping(monitor='val_accuracy', patience=50,mode='max')
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint,early_stop]

history2 = fin_model.fit([train_images,stack_tr], train_labels, batch_size=100, epochs=20
                        ,validation_data=([test_images,stack_ts], test_labels),
                         callbacks = callbacks_list,
                        )
# Out:
# Epoch 1/20
# 100/100 [==============================] - ETA: 0s - loss: 1.2990 - accuracy: 0.6846 - categorical_crossentropy: 0.9638
# Epoch 1: val_accuracy improved from -inf to 0.91970, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_ORB(only)NET_MNIST_best_weights.hdf5
# 100/100 [==============================] - 28s 271ms/step - loss: 1.2990 - accuracy: 0.6846 - categorical_crossentropy: 0.9638 - val_loss: 0.4276 - val_accuracy: 0.9197 - val_categorical_crossentropy: 0.2921
# Epoch 2/20
# 100/100 [==============================] - ETA: 0s - loss: 0.6231 - accuracy: 0.8222 - categorical_crossentropy: 0.5587
# Epoch 2: val_accuracy improved from 0.91970 to 0.94290, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_ORB(only)NET_MNIST_best_weights.hdf5
# 100/100 [==============================] - 27s 272ms/step - loss: 0.6231 - accuracy: 0.8222 - categorical_crossentropy: 0.5587 - val_loss: 0.2065 - val_accuracy: 0.9429 - val_categorical_crossentropy: 0.1845
# Epoch 3/20
# 100/100 [==============================] - ETA: 0s - loss: 0.4500 - accuracy: 0.8631 - categorical_crossentropy: 0.4407
# Epoch 3: val_accuracy improved from 0.94290 to 0.95420, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_ORB(only)NET_MNIST_best_weights.hdf5
# 100/100 [==============================] - 27s 272ms/step - loss: 0.4500 - accuracy: 0.8631 - categorical_crossentropy: 0.4407 - val_loss: 0.1587 - val_accuracy: 0.9542 - val_categorical_crossentropy: 0.1561
# Epoch 4/20
# 100/100 [==============================] - ETA: 0s - loss: 0.3852 - accuracy: 0.8759 - categorical_crossentropy: 0.3843
# Epoch 4: val_accuracy did not improve from 0.95420
# 100/100 [==============================] - 28s 279ms/step - loss: 0.3852 - accuracy: 0.8759 - categorical_crossentropy: 0.3843 - val_loss: 0.1518 - val_accuracy: 0.9529 - val_categorical_crossentropy: 0.1516
# Epoch 5/20
# 100/100 [==============================] - ETA: 0s - loss: 0.3413 - accuracy: 0.8908 - categorical_crossentropy: 0.3412
# Epoch 5: val_accuracy improved from 0.95420 to 0.96300, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_ORB(only)NET_MNIST_best_weights.hdf5
# 100/100 [==============================] - 28s 278ms/step - loss: 0.3413 - accuracy: 0.8908 - categorical_crossentropy: 0.3412 - val_loss: 0.1197 - val_accuracy: 0.9630 - val_categorical_crossentropy: 0.1197
# Epoch 6/20
# 100/100 [==============================] - ETA: 0s - loss: 0.3176 - accuracy: 0.8958 - categorical_crossentropy: 0.3176
# Epoch 6: val_accuracy improved from 0.96300 to 0.96470, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_ORB(only)NET_MNIST_best_weights.hdf5
# 100/100 [==============================] - 27s 270ms/step - loss: 0.3176 - accuracy: 0.8958 - categorical_crossentropy: 0.3176 - val_loss: 0.1166 - val_accuracy: 0.9647 - val_categorical_crossentropy: 0.1166
# Epoch 7/20
# 100/100 [==============================] - ETA: 0s - loss: 0.2910 - accuracy: 0.9056 - categorical_crossentropy: 0.2910
# Epoch 7: val_accuracy improved from 0.96470 to 0.96850, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_ORB(only)NET_MNIST_best_weights.hdf5
# 100/100 [==============================] - 28s 276ms/step - loss: 0.2910 - accuracy: 0.9056 - categorical_crossentropy: 0.2910 - val_loss: 0.1060 - val_accuracy: 0.9685 - val_categorical_crossentropy: 0.1060
# Epoch 8/20
# 100/100 [==============================] - ETA: 0s - loss: 0.2722 - accuracy: 0.9110 - categorical_crossentropy: 0.2722
# Epoch 8: val_accuracy improved from 0.96850 to 0.96930, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_ORB(only)NET_MNIST_best_weights.hdf5
# 100/100 [==============================] - 27s 268ms/step - loss: 0.2722 - accuracy: 0.9110 - categorical_crossentropy: 0.2722 - val_loss: 0.1036 - val_accuracy: 0.9693 - val_categorical_crossentropy: 0.1036
# Epoch 9/20
# 100/100 [==============================] - ETA: 0s - loss: 0.2545 - accuracy: 0.9138 - categorical_crossentropy: 0.2545
# Epoch 9: val_accuracy improved from 0.96930 to 0.97020, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_ORB(only)NET_MNIST_best_weights.hdf5
# 100/100 [==============================] - 29s 293ms/step - loss: 0.2545 - accuracy: 0.9138 - categorical_crossentropy: 0.2545 - val_loss: 0.1042 - val_accuracy: 0.9702 - val_categorical_crossentropy: 0.1042
# Epoch 10/20
# 100/100 [==============================] - ETA: 0s - loss: 0.2507 - accuracy: 0.9151 - categorical_crossentropy: 0.2507
# Epoch 10: val_accuracy did not improve from 0.97020
# 100/100 [==============================] - 32s 323ms/step - loss: 0.2507 - accuracy: 0.9151 - categorical_crossentropy: 0.2507 - val_loss: 0.1004 - val_accuracy: 0.9700 - val_categorical_crossentropy: 0.1004
# Epoch 11/20
# 100/100 [==============================] - ETA: 0s - loss: 0.2344 - accuracy: 0.9222 - categorical_crossentropy: 0.2344
# Epoch 11: val_accuracy improved from 0.97020 to 0.97150, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_ORB(only)NET_MNIST_best_weights.hdf5
# 100/100 [==============================] - 27s 268ms/step - loss: 0.2344 - accuracy: 0.9222 - categorical_crossentropy: 0.2344 - val_loss: 0.0955 - val_accuracy: 0.9715 - val_categorical_crossentropy: 0.0955
# Epoch 12/20
# 100/100 [==============================] - ETA: 0s - loss: 0.2220 - accuracy: 0.9252 - categorical_crossentropy: 0.2220
# Epoch 12: val_accuracy improved from 0.97150 to 0.97270, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_ORB(only)NET_MNIST_best_weights.hdf5
# 100/100 [==============================] - 27s 269ms/step - loss: 0.2220 - accuracy: 0.9252 - categorical_crossentropy: 0.2220 - val_loss: 0.0957 - val_accuracy: 0.9727 - val_categorical_crossentropy: 0.0957
# Epoch 13/20
# 100/100 [==============================] - ETA: 0s - loss: 0.2137 - accuracy: 0.9281 - categorical_crossentropy: 0.2137
# Epoch 13: val_accuracy did not improve from 0.97270
# 100/100 [==============================] - 27s 267ms/step - loss: 0.2137 - accuracy: 0.9281 - categorical_crossentropy: 0.2137 - val_loss: 0.0946 - val_accuracy: 0.9727 - val_categorical_crossentropy: 0.0946
# Epoch 14/20
# 100/100 [==============================] - ETA: 0s - loss: 0.2124 - accuracy: 0.9319 - categorical_crossentropy: 0.2124
# Epoch 14: val_accuracy did not improve from 0.97270
# 100/100 [==============================] - 26s 265ms/step - loss: 0.2124 - accuracy: 0.9319 - categorical_crossentropy: 0.2124 - val_loss: 0.0998 - val_accuracy: 0.9725 - val_categorical_crossentropy: 0.0998
# Epoch 15/20
# 100/100 [==============================] - ETA: 0s - loss: 0.2044 - accuracy: 0.9328 - categorical_crossentropy: 0.2044
# Epoch 15: val_accuracy improved from 0.97270 to 0.97570, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_ORB(only)NET_MNIST_best_weights.hdf5
# 100/100 [==============================] - 27s 273ms/step - loss: 0.2044 - accuracy: 0.9328 - categorical_crossentropy: 0.2044 - val_loss: 0.0849 - val_accuracy: 0.9757 - val_categorical_crossentropy: 0.0849
# Epoch 16/20
# 100/100 [==============================] - ETA: 0s - loss: 0.2032 - accuracy: 0.9309 - categorical_crossentropy: 0.2032
# Epoch 16: val_accuracy did not improve from 0.97570
# 100/100 [==============================] - 27s 266ms/step - loss: 0.2032 - accuracy: 0.9309 - categorical_crossentropy: 0.2032 - val_loss: 0.0873 - val_accuracy: 0.9749 - val_categorical_crossentropy: 0.0873
# Epoch 17/20
# 100/100 [==============================] - ETA: 0s - loss: 0.1895 - accuracy: 0.9352 - categorical_crossentropy: 0.1895
# Epoch 17: val_accuracy did not improve from 0.97570
# 100/100 [==============================] - 27s 267ms/step - loss: 0.1895 - accuracy: 0.9352 - categorical_crossentropy: 0.1895 - val_loss: 0.0900 - val_accuracy: 0.9731 - val_categorical_crossentropy: 0.0900
# Epoch 18/20
# 100/100 [==============================] - ETA: 0s - loss: 0.1904 - accuracy: 0.9340 - categorical_crossentropy: 0.1904
# Epoch 18: val_accuracy improved from 0.97570 to 0.97690, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_ORB(only)NET_MNIST_best_weights.hdf5
# 100/100 [==============================] - 29s 295ms/step - loss: 0.1904 - accuracy: 0.9340 - categorical_crossentropy: 0.1904 - val_loss: 0.0911 - val_accuracy: 0.9769 - val_categorical_crossentropy: 0.0911
# Epoch 19/20
# 100/100 [==============================] - ETA: 0s - loss: 0.1948 - accuracy: 0.9349 - categorical_crossentropy: 0.1948
# Epoch 19: val_accuracy did not improve from 0.97690
# 100/100 [==============================] - 27s 268ms/step - loss: 0.1948 - accuracy: 0.9349 - categorical_crossentropy: 0.1948 - val_loss: 0.1006 - val_accuracy: 0.9730 - val_categorical_crossentropy: 0.1006
# Epoch 20/20
# 100/100 [==============================] - ETA: 0s - loss: 0.1877 - accuracy: 0.9364 - categorical_crossentropy: 0.1877
# Epoch 20: val_accuracy did not improve from 0.97690
# 100/100 [==============================] - 27s 267ms/step - loss: 0.1877 - accuracy: 0.9364 - categorical_crossentropy: 0.1877 - val_loss: 0.0902 - val_accuracy: 0.9748 - val_categorical_crossentropy: 0.0902

# %%
accuracy = history2.history['accuracy']
val_accuracy = history2.history['val_accuracy']

plt.figure()
plt.plot(accuracy, label='accuracy')
plt.plot(val_accuracy, label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.3, 1])
plt.legend(loc='lower right')
plt.show()

# %%
loss = history2.history['loss']
val_loss = history2.history['val_loss']

plt.figure()
plt.plot(loss, label='loss')
plt.plot(val_loss, label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# We can see that, using the tuned discriminator model, both training accuracy and testing are approximately 0.90 after 15 epochs.

# %%
stack_ts[i].shape, stack_ts[i].reshape(1,64).shape, test_images[i].shape, test_images[i].reshape(1,28,28,1).shape
# Out:
# ((64,), (1, 64), (28, 28, 1), (1, 28, 28, 1))

# %%
# demonstration: predict the ith test digit
i = 15
prediction = fin_model.predict([test_images[i].reshape(1,28,28,1),stack_ts[i].reshape(1,64)])

# get probability distribution and classification of the test digit
print(prediction)
print('prediction:', np.argmax(prediction))

# draw the barplot
plt.figure()
plt.bar(np.arange(0,10).astype('str'), prediction[0,:])
plt.show()
# Out:
# 1/1 [==============================] - 0s 119ms/step
# [[8.3289322e-12 1.4878073e-06 9.9999046e-01 1.0919830e-06 1.4802114e-12
#   2.6583914e-13 1.8970940e-12 2.8718455e-07 6.6398989e-06 2.4946404e-15]]
# prediction: 2

# %%
# show the actual ith digit
print('actual label:', np.argmax(test_labels[i]))
plt.figure()
plt.imshow(test_images[i,:,:,0], cmap='gray')
plt.show()
# Out:
# actual label: 2

# %%
pred_labels = fin_model.predict([test_images,stack_ts]).argmax(axis=1)
true_labels = test_labels.argmax(axis=1)
# Out:
# 313/313 [==============================] - 6s 19ms/step

# %%
from sklearn.metrics import confusion_matrix
confusion_mat = confusion_matrix(true_labels, pred_labels)
confusion_mat
# Out:
# array([[ 973,    0,    1,    0,    0,    0,    4,    1,    1,    0],
#        [   0, 1125,    4,    1,    0,    1,    3,    1,    0,    0],
#        [   4,    1,  999,    3,    6,    0,    3,    9,    6,    1],
#        [   0,    0,    5,  992,    0,    0,    0,    8,    3,    2],
#        [   1,    0,    1,    0,  959,    0,    5,    1,    2,   13],
#        [   2,    1,    0,   19,    0,  855,    7,    1,    5,    2],
#        [   6,    3,    0,    0,    5,    1,  942,    0,    1,    0],
#        [   2,    1,   14,    1,    2,    1,    0,  995,    2,   10],
#        [   8,    0,    7,    4,    2,    0,    2,    5,  940,    6],
#        [   5,    3,    1,    9,   10,    4,    0,    6,    3,  968]])

# %%
import pandas as pd
import seaborn as sns

confusion_mat_norm = np.around(confusion_mat.astype('float') / np.atleast_2d(confusion_mat.sum(axis=1)).T, decimals=2)

classes = np.arange(0,10).astype('str')
confusion_mat_df = pd.DataFrame(confusion_mat_norm,
                                index = classes, 
                                columns = classes)

figure = plt.figure()
sns.heatmap(confusion_mat_df, annot=True, cmap=plt.cm.Blues)
plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
