# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential, layers
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Activation, Flatten, BatchNormalization, Input ,concatenate
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import  EarlyStopping, ModelCheckpoint
import glob
import os
import PIL
import time
# !pip install emnist

from IPython import display
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting emnist
#   Downloading emnist-0.0-py3-none-any.whl (7.3 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from emnist) (4.64.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from emnist) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from emnist) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->emnist) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->emnist) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->emnist) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->emnist) (1.24.3)
# Installing collected packages: emnist
# Successfully installed emnist-0.0

# %%
def make_generator_model():
    model = tf.keras.Sequential()
    model.add(layers.Dense(7*7*256, use_bias=False, input_shape=(100,)))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Reshape((7, 7, 256)))
    assert model.output_shape == (None, 7, 7, 256) # Note: None is the batch size

    model.add(layers.Conv2DTranspose(128, (5, 5), strides=(1, 1), padding='same', use_bias=False))
    assert model.output_shape == (None, 7, 7, 128)
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Conv2DTranspose(64, (5, 5), strides=(2, 2), padding='same', use_bias=False))
    assert model.output_shape == (None, 14, 14, 64)
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Conv2DTranspose(1, (5, 5), strides=(2, 2), padding='same', use_bias=False, activation='tanh'))
    assert model.output_shape == (None, 28, 28, 1)

    return model

# %%
def make_discriminator_model():
    model = tf.keras.Sequential()
    model.add(layers.Conv2D(64, (5, 5), strides=(2, 2), padding='same',
                                     input_shape=[28, 28, 1]))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))

    model.add(layers.Conv2D(128, (5, 5), strides=(2, 2), padding='same'))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))

    model.add(layers.Flatten())
    model.add(layers.Dense(1))

    return model

# %%
generator = make_generator_model()
discriminator = make_discriminator_model()
generator_optimizer = tf.keras.optimizers.Adam(1e-4)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)

# %%
checkpoint_dir = '/content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/training_checkpoints_EMNIST'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer,
                                 generator=generator,
                                 discriminator=discriminator)

# %%
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
noi = tf.random.normal([1, 100])
sample = checkpoint.generator(noi, training=False)
plt.imshow(sample[0, :, :, 0], cmap='gray')

# %%
disc = checkpoint.discriminator
disc.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 14, 14, 64)        1664
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 14, 14, 64)        0
#
#  dropout (Dropout)           (None, 14, 14, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 128)         204928
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 7, 7, 128)         0
#
#  dropout_1 (Dropout)         (None, 7, 7, 128)         0
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense_1 (Dense)             (None, 1)                 6273
#
# =================================================================
# Total params: 212,865
# Trainable params: 212,865
# Non-trainable params: 0
# _________________________________________________________________

# %%
val = disc(sample)
print (val)
# Out:
# tf.Tensor([[-1.4654498]], shape=(1, 1), dtype=float32)

# %% [markdown]
# Now, we transfer the weights of discriminator to a new model, with the only difference being that the new model's last dense layer has 10 parameters instead of 1.

# %%
new_model = Sequential()

for i in range(len(disc.layers) - 1):
    new_model.add(disc.layers[i])

# Freeze the layers 
for layer in new_model.layers:
    layer.trainable = True  #Unfreezed as True

new_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 14, 14, 64)        1664
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 14, 14, 64)        0
#
#  dropout (Dropout)           (None, 14, 14, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 128)         204928
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 7, 7, 128)         0
#
#  dropout_1 (Dropout)         (None, 7, 7, 128)         0
#
#  flatten (Flatten)           (None, 6272)              0
#
# =================================================================
# Total params: 206,592
# Trainable params: 206,592
# Non-trainable params: 0
# _________________________________________________________________

# %%
# view the initialized weights and bias of the last dense layer; weights are uniformly randomly generated 
# and biases are all zeroes by default
new_model.layers[-1].weights
# Out:
# []

# %%
from emnist import extract_training_samples, extract_test_samples
train_img, train_lb = extract_training_samples('letters')
test_img, test_lb = extract_test_samples('letters')

print(train_img.shape, train_lb.shape, test_img.shape, test_lb.shape, '\n')

# set random seed
np.random.seed(42)
trainsize = 30000  # number of training images we use, selected randomly
randtrain = np.random.choice(train_img.shape[0], trainsize, replace=False)
X_train, y_train = train_img[randtrain], train_lb[randtrain]

np.random.seed(10)
testsize = 10000  # number of testing images we use, selected randomly
randtest = np.random.choice(test_img.shape[0], testsize, replace=False)
X_test, y_test = test_img[randtest], test_lb[randtest]

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# Downloading emnist.zip: 536MB [00:36, 15.4MB/s]
# (124800, 28, 28) (124800,) (20800, 28, 28) (20800,)
#
# (30000, 28, 28) (30000,) (10000, 28, 28) (10000,)

# %%
train_images = X_train.reshape((trainsize, 28, 28, 1))
train_images = (train_images.astype('float32') - 127.5) / 127.5

test_images = X_test.reshape((testsize, 28, 28, 1))
test_images = (test_images.astype('float32') - 127.5) / 127.5

train_labels = to_categorical(y_train)
test_labels = to_categorical(y_test)

# %%
import skimage.data as skid
import cv2
import pylab as plt
import numpy as np
import cv2
from sklearn.cluster import MiniBatchKMeans
import pickle
import tqdm.notebook as tqdm

def generate_vector(gray):
  Detector = cv2.xfeatures2d.SIFT_create() ## cv2.FastFeatureDetector.create()
  Descriptor = cv2.xfeatures2d.SIFT_create()
  vector_64 = np.zeros(64,dtype='uint8')
  step_size = 5
  kp = [cv2.KeyPoint(x, y, step_size) for y in range(0, gray.shape[0], step_size) 
                                      for x in range(0, gray.shape[1], step_size)]
  kp, desc = Descriptor.compute(gray, kp)
  kmeans = MiniBatchKMeans(n_clusters=8, n_init=10)
  kmeans.fit(desc)
  predictions = kmeans.predict(X=desc,  sample_weight=None)
  for pre in predictions:
    vector_64[pre] +=1
  return vector_64

# multiple images train
stack_tr = generate_vector(X_train[0])
count = 0
for img in tqdm.tqdm(X_train[1:]):
    vector = generate_vector(img)
    stack_tr = np.vstack((stack_tr,vector))
    count +=1
print("Histogram Generated for training set! ")
# multiple images train
stack_ts = generate_vector(X_test[0])
count = 0
for img in tqdm.tqdm(X_test[1:]):
    vector = generate_vector(img)
    stack_ts = np.vstack((stack_ts,vector))
    count +=1
print("Histogram Generated for testing set! ")
# Out:
#   0%|          | 0/29999 [00:00<?, ?it/s]
# Histogram Generated for training set!
#   0%|          | 0/9999 [00:00<?, ?it/s]
# Histogram Generated for testing set!

# %%
# np.save("/content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/EMNIST_SIFT_histogram_train.npy",stack_tr)
# np.save("/content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/EMNIST_SIFT_histogram_test.npy",stack_ts)
#
stack_tr = np.load("/content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/EMNIST_SIFT_histogram_train.npy")
stack_ts = np.load("/content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/EMNIST_SIFT_histogram_test.npy")

# %%
def ExtractFeatures_Layer(dim):
    model = Sequential()
    model.add(Dense(64,input_dim=dim,kernel_regularizer=l2(0.01)
                    ))
    model.add(Dropout(0.5))
    return model
DSIFT = ExtractFeatures_Layer(stack_tr.shape[1])
MergeModel = concatenate([new_model.output, DSIFT.output])

# %%
# new_model.add(Dense(10, activation='softmax'))
m = Dense(32, activation='relu')(MergeModel)
m = Dropout(0.5)(m)
m = Dense(27, activation='softmax')(m)

fin_model = Model(inputs=[new_model.input, DSIFT.input], outputs=m)
fin_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  conv2d_input (InputLayer)      [(None, 28, 28, 1)]  0           []
#
#  conv2d (Conv2D)                (None, 14, 14, 64)   1664        ['conv2d_input[0][0]']
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 14, 14, 64)   0           ['conv2d[1][0]']
#
#  dropout (Dropout)              (None, 14, 14, 64)   0           ['leaky_re_lu_3[1][0]']
#
#  conv2d_1 (Conv2D)              (None, 7, 7, 128)    204928      ['dropout[1][0]']
#
#  leaky_re_lu_4 (LeakyReLU)      (None, 7, 7, 128)    0           ['conv2d_1[1][0]']
#
#  dense_2_input (InputLayer)     [(None, 64)]         0           []
#
#  dropout_1 (Dropout)            (None, 7, 7, 128)    0           ['leaky_re_lu_4[1][0]']
#
#  dense_2 (Dense)                (None, 64)           4160        ['dense_2_input[0][0]']
#
#  flatten (Flatten)              (None, 6272)         0           ['dropout_1[1][0]']
#
#  dropout_2 (Dropout)            (None, 64)           0           ['dense_2[0][0]']
#
#  concatenate (Concatenate)      (None, 6336)         0           ['flatten[1][0]',
#                                                                   'dropout_2[0][0]']
#
#  dense_3 (Dense)                (None, 32)           202784      ['concatenate[0][0]']
#
#  dropout_3 (Dropout)            (None, 32)           0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 27)           891         ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 414,427
# Trainable params: 414,427
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
fin_model.compile(Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-7),
                  loss='categorical_crossentropy',
                  metrics=['accuracy',tf.keras.metrics.CategoricalCrossentropy()])

# %%
train_images.shape, stack_tr.shape, train_labels.shape, stack_ts.shape
# Out:
# ((30000, 28, 28, 1), (30000, 64), (30000, 27), (10000, 64))

# %%
filepath = "/content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_SIFTNET_"+"EMNIST"+"_best_weights.hdf5"
early_stop = EarlyStopping(monitor='val_accuracy', patience=50,mode='max')
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint,early_stop]

history2 = fin_model.fit([train_images,stack_tr], train_labels, batch_size=100, epochs=20
                        ,validation_data=([test_images,stack_ts], test_labels),
                         callbacks = callbacks_list,
                        )
# Out:
# Epoch 1/20
# 300/300 [==============================] - ETA: 0s - loss: 2.0159 - accuracy: 0.4338 - categorical_crossentropy: 1.8951
# Epoch 1: val_accuracy improved from -inf to 0.77920, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_SIFTNET_EMNIST_best_weights.hdf5
# 300/300 [==============================] - 69s 231ms/step - loss: 2.0159 - accuracy: 0.4338 - categorical_crossentropy: 1.8951 - val_loss: 0.8823 - val_accuracy: 0.7792 - val_categorical_crossentropy: 0.8626
# Epoch 2/20
# 300/300 [==============================] - ETA: 0s - loss: 1.3192 - accuracy: 0.5860 - categorical_crossentropy: 1.3093
# Epoch 2: val_accuracy improved from 0.77920 to 0.82060, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_SIFTNET_EMNIST_best_weights.hdf5
# 300/300 [==============================] - 69s 231ms/step - loss: 1.3192 - accuracy: 0.5860 - categorical_crossentropy: 1.3093 - val_loss: 0.6240 - val_accuracy: 0.8206 - val_categorical_crossentropy: 0.6196
# Epoch 3/20
# 300/300 [==============================] - ETA: 0s - loss: 1.1597 - accuracy: 0.6270 - categorical_crossentropy: 1.1575
# Epoch 3: val_accuracy improved from 0.82060 to 0.83360, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_SIFTNET_EMNIST_best_weights.hdf5
# 300/300 [==============================] - 70s 234ms/step - loss: 1.1597 - accuracy: 0.6270 - categorical_crossentropy: 1.1575 - val_loss: 0.5451 - val_accuracy: 0.8336 - val_categorical_crossentropy: 0.5441
# Epoch 4/20
# 300/300 [==============================] - ETA: 0s - loss: 1.0527 - accuracy: 0.6587 - categorical_crossentropy: 1.0521
# Epoch 4: val_accuracy improved from 0.83360 to 0.85330, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_SIFTNET_EMNIST_best_weights.hdf5
# 300/300 [==============================] - 71s 236ms/step - loss: 1.0527 - accuracy: 0.6587 - categorical_crossentropy: 1.0521 - val_loss: 0.4924 - val_accuracy: 0.8533 - val_categorical_crossentropy: 0.4921
# Epoch 5/20
# 300/300 [==============================] - ETA: 0s - loss: 1.0015 - accuracy: 0.6741 - categorical_crossentropy: 1.0013
# Epoch 5: val_accuracy improved from 0.85330 to 0.85680, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_SIFTNET_EMNIST_best_weights.hdf5
# 300/300 [==============================] - 69s 230ms/step - loss: 1.0015 - accuracy: 0.6741 - categorical_crossentropy: 1.0013 - val_loss: 0.4630 - val_accuracy: 0.8568 - val_categorical_crossentropy: 0.4628
# Epoch 6/20
# 300/300 [==============================] - ETA: 0s - loss: 0.9598 - accuracy: 0.6826 - categorical_crossentropy: 0.9596
# Epoch 6: val_accuracy improved from 0.85680 to 0.85730, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_SIFTNET_EMNIST_best_weights.hdf5
# 300/300 [==============================] - 69s 229ms/step - loss: 0.9598 - accuracy: 0.6826 - categorical_crossentropy: 0.9596 - val_loss: 0.4572 - val_accuracy: 0.8573 - val_categorical_crossentropy: 0.4570
# Epoch 7/20
# 300/300 [==============================] - ETA: 0s - loss: 0.9394 - accuracy: 0.6867 - categorical_crossentropy: 0.9393
# Epoch 7: val_accuracy improved from 0.85730 to 0.86190, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_SIFTNET_EMNIST_best_weights.hdf5
# 300/300 [==============================] - 71s 237ms/step - loss: 0.9394 - accuracy: 0.6867 - categorical_crossentropy: 0.9393 - val_loss: 0.4291 - val_accuracy: 0.8619 - val_categorical_crossentropy: 0.4289
# Epoch 8/20
# 300/300 [==============================] - ETA: 0s - loss: 0.9084 - accuracy: 0.6961 - categorical_crossentropy: 0.9082
# Epoch 8: val_accuracy improved from 0.86190 to 0.87580, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_SIFTNET_EMNIST_best_weights.hdf5
# 300/300 [==============================] - 69s 230ms/step - loss: 0.9084 - accuracy: 0.6961 - categorical_crossentropy: 0.9082 - val_loss: 0.4017 - val_accuracy: 0.8758 - val_categorical_crossentropy: 0.4015
# Epoch 9/20
# 300/300 [==============================] - ETA: 0s - loss: 0.8972 - accuracy: 0.7005 - categorical_crossentropy: 0.8971
# Epoch 9: val_accuracy did not improve from 0.87580
# 300/300 [==============================] - 68s 227ms/step - loss: 0.8972 - accuracy: 0.7005 - categorical_crossentropy: 0.8971 - val_loss: 0.4162 - val_accuracy: 0.8751 - val_categorical_crossentropy: 0.4160
# Epoch 10/20
# 300/300 [==============================] - ETA: 0s - loss: 0.8760 - accuracy: 0.7057 - categorical_crossentropy: 0.8759
# Epoch 10: val_accuracy did not improve from 0.87580
# 300/300 [==============================] - 68s 227ms/step - loss: 0.8760 - accuracy: 0.7057 - categorical_crossentropy: 0.8759 - val_loss: 0.4070 - val_accuracy: 0.8733 - val_categorical_crossentropy: 0.4069
# Epoch 11/20
# 300/300 [==============================] - ETA: 0s - loss: 0.8694 - accuracy: 0.7075 - categorical_crossentropy: 0.8693
# Epoch 11: val_accuracy did not improve from 0.87580
# 300/300 [==============================] - 70s 235ms/step - loss: 0.8694 - accuracy: 0.7075 - categorical_crossentropy: 0.8693 - val_loss: 0.4146 - val_accuracy: 0.8710 - val_categorical_crossentropy: 0.4145
# Epoch 12/20
# 300/300 [==============================] - ETA: 0s - loss: 0.8481 - accuracy: 0.7157 - categorical_crossentropy: 0.8480
# Epoch 12: val_accuracy improved from 0.87580 to 0.88250, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_SIFTNET_EMNIST_best_weights.hdf5
# 300/300 [==============================] - 69s 231ms/step - loss: 0.8481 - accuracy: 0.7157 - categorical_crossentropy: 0.8480 - val_loss: 0.3832 - val_accuracy: 0.8825 - val_categorical_crossentropy: 0.3831
# Epoch 13/20
# 300/300 [==============================] - ETA: 0s - loss: 0.8369 - accuracy: 0.7159 - categorical_crossentropy: 0.8368
# Epoch 13: val_accuracy did not improve from 0.88250
# 300/300 [==============================] - 68s 228ms/step - loss: 0.8369 - accuracy: 0.7159 - categorical_crossentropy: 0.8368 - val_loss: 0.3992 - val_accuracy: 0.8791 - val_categorical_crossentropy: 0.3991
# Epoch 14/20
# 300/300 [==============================] - ETA: 0s - loss: 0.8346 - accuracy: 0.7186 - categorical_crossentropy: 0.8345
# Epoch 14: val_accuracy did not improve from 0.88250
# 300/300 [==============================] - 68s 227ms/step - loss: 0.8346 - accuracy: 0.7186 - categorical_crossentropy: 0.8345 - val_loss: 0.3864 - val_accuracy: 0.8781 - val_categorical_crossentropy: 0.3863
# Epoch 15/20
# 300/300 [==============================] - ETA: 0s - loss: 0.8184 - accuracy: 0.7217 - categorical_crossentropy: 0.8183
# Epoch 15: val_accuracy did not improve from 0.88250
# 300/300 [==============================] - 70s 233ms/step - loss: 0.8184 - accuracy: 0.7217 - categorical_crossentropy: 0.8183 - val_loss: 0.3825 - val_accuracy: 0.8814 - val_categorical_crossentropy: 0.3823
# Epoch 16/20
# 300/300 [==============================] - ETA: 0s - loss: 0.8182 - accuracy: 0.7264 - categorical_crossentropy: 0.8181
# Epoch 16: val_accuracy improved from 0.88250 to 0.88300, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_SIFTNET_EMNIST_best_weights.hdf5
# 300/300 [==============================] - 68s 228ms/step - loss: 0.8182 - accuracy: 0.7264 - categorical_crossentropy: 0.8181 - val_loss: 0.3871 - val_accuracy: 0.8830 - val_categorical_crossentropy: 0.3870
# Epoch 17/20
# 300/300 [==============================] - ETA: 0s - loss: 0.8095 - accuracy: 0.7274 - categorical_crossentropy: 0.8093
# Epoch 17: val_accuracy did not improve from 0.88300
# 300/300 [==============================] - 68s 227ms/step - loss: 0.8095 - accuracy: 0.7274 - categorical_crossentropy: 0.8093 - val_loss: 0.3756 - val_accuracy: 0.8774 - val_categorical_crossentropy: 0.3754
# Epoch 18/20
# 300/300 [==============================] - ETA: 0s - loss: 0.7989 - accuracy: 0.7269 - categorical_crossentropy: 0.7987
# Epoch 18: val_accuracy improved from 0.88300 to 0.88430, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_SIFTNET_EMNIST_best_weights.hdf5
# 300/300 [==============================] - 69s 231ms/step - loss: 0.7989 - accuracy: 0.7269 - categorical_crossentropy: 0.7987 - val_loss: 0.3774 - val_accuracy: 0.8843 - val_categorical_crossentropy: 0.3772
# Epoch 19/20
# 300/300 [==============================] - ETA: 0s - loss: 0.8051 - accuracy: 0.7297 - categorical_crossentropy: 0.8050
# Epoch 19: val_accuracy did not improve from 0.88430
# 300/300 [==============================] - 78s 259ms/step - loss: 0.8051 - accuracy: 0.7297 - categorical_crossentropy: 0.8050 - val_loss: 0.3841 - val_accuracy: 0.8841 - val_categorical_crossentropy: 0.3840
# Epoch 20/20
# 300/300 [==============================] - ETA: 0s - loss: 0.7889 - accuracy: 0.7347 - categorical_crossentropy: 0.7887
# Epoch 20: val_accuracy improved from 0.88430 to 0.89020, saving model to /content/drive/MyDrive/Colab Notebooks/SIFT+GAN handwriting/GAN_SIFTNET_EMNIST_best_weights.hdf5
# 300/300 [==============================] - 76s 252ms/step - loss: 0.7889 - accuracy: 0.7347 - categorical_crossentropy: 0.7887 - val_loss: 0.3658 - val_accuracy: 0.8902 - val_categorical_crossentropy: 0.3657

# %%
accuracy = history2.history['accuracy']
val_accuracy = history2.history['val_accuracy']

plt.figure()
plt.plot(accuracy, label='accuracy')
plt.plot(val_accuracy, label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.3, 1])
plt.legend(loc='lower right')
plt.show()

# %%
loss = history2.history['loss']
val_loss = history2.history['val_loss']

plt.figure()
plt.plot(loss, label='loss')
plt.plot(val_loss, label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# We can see that, using the tuned discriminator model, both training accuracy and testing are approximately 0.90 after 15 epochs.

# %%
stack_ts[i].shape, stack_ts[i].reshape(1,64).shape, test_images[i].shape, test_images[i].reshape(1,28,28,1).shape

# %%
# demonstration: predict the ith test digit
i = 15
prediction = fin_model.predict([test_images[i].reshape(1,28,28,1),stack_ts[i].reshape(1,64)])

# get probability distribution and classification of the test digit
print(prediction)
print('prediction:', np.argmax(prediction))

# draw the barplot
plt.figure()
plt.bar(np.arange(0,27).astype('str'), prediction[0,:])
plt.show()

# %%
# show the actual ith digit
print('actual label:', np.argmax(test_labels[i]))
plt.figure()
plt.imshow(test_images[i,:,:,0], cmap='gray')
plt.show()

# %%
pred_labels = fin_model.predict([test_images,stack_ts]).argmax(axis=1)
true_labels = test_labels.argmax(axis=1)

# %%
from sklearn.metrics import confusion_matrix
confusion_mat = confusion_matrix(true_labels, pred_labels)
confusion_mat

# %%
import pandas as pd
import seaborn as sns

confusion_mat_norm = np.around(confusion_mat.astype('float') / np.atleast_2d(confusion_mat.sum(axis=1)).T, decimals=2)

classes = np.arange(0,26).astype('str')
confusion_mat_df = pd.DataFrame(confusion_mat_norm,
                                index = classes, 
                                columns = classes)

figure = plt.figure()
sns.heatmap(confusion_mat_df, annot=True, cmap=plt.cm.Blues)
plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
